# %% [markdown]
# # Часть про обработку Nanов и визуализацию

# %% [markdown]
# <img src="SUf8TTOEqy0.jpg" width="500" height="340">

# %% [markdown]
# # II) Обработка данных

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import scipy.stats as sts

import warnings
warnings.filterwarnings("ignore")

# %%
df_a = pd.read_csv('auto.csv', index_col=[0])
df_b = pd.read_csv('auto1.csv', index_col=[0])
df_c = pd.read_csv('auto2.csv', index_col=[0])
df_d = pd.read_csv('auto3.csv', index_col=[0])
# index_col=[0] чтобы не было лишнего столбца unnamed: 0

# %% [markdown]
# Создаем дополнительный датафрейм, который не будем изменять, чтобы сверяться, если что-то пойдет не так

# %%
df_1 = pd.read_csv('auto.csv', index_col=[0])
df_2 = pd.read_csv('auto1.csv', index_col=[0])
df_3 = pd.read_csv('auto2.csv', index_col=[0])
df_4 = pd.read_csv('auto3.csv', index_col=[0])

# %%
df = pd.concat([df_a, df_b, df_c, df_d], ignore_index=True) # соединяем четыре датафрейма
df1 = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)

# %%
#во-первых, у нас встречаются дубликаты из-за перекупов-дудосатакеров на дроме. Исправляем:
df.drop_duplicates(inplace = True, ignore_index = True ) #перезаписываем и сбрасываем индексы
df1.drop_duplicates(inplace = True, ignore_index = True )

# %%
#во время парсинга пустые значения заполнялись пустой строкой, по факту это - NaN. Заменим на настоящие NaN
df.replace('', np.NaN, inplace = True) #сразу перезаписываем таблицу
df1.replace('', np.NaN, inplace = True)

# %% [markdown]
# ### Что за данные у нас вообще получились?

# %%
df.head()
# Out:
#            Название   Год Топливо  Объем двигателя  Мощность Коробка передач  \
# 0        Kia Mohave  2020  дизель              3.0     260.0         автомат
# 1  Hyundai Santa Fe  2018  дизель              2.2     200.0            АКПП
# 2       Toyota RAV4  2022  бензин              2.0     173.0        вариатор
# 3    Jeep Gladiator  2020  бензин              3.6     285.0            АКПП
# 4     Jeep Wrangler  2018  бензин              2.0     272.0            АКПП
#
#   Привод    Цвет   Пробег   Руль  Оценка Drom     Цена
# 0    4WD   серый  26000.0  левый          8.8  4650000
# 1    4WD   серый  81000.0  левый          8.7  2850000
# 2    4WD  черный      1.0  левый          8.7  4000000
# 3    4WD  черный  15000.0  левый          NaN  6750000
# 4    4WD  черный  37700.0  левый          8.7  5200000

# %%
df.describe()
# Out:
#                Год  Объем двигателя     Мощность         Пробег  Оценка Drom  \
# count  1390.000000      1375.000000  1337.000000    1101.000000   853.000000
# mean   2016.328777         2.170255   187.021690  112515.642144     8.601524
# std       6.463318         0.824389    98.842305   81255.735399     0.275587
# min    1950.000000         0.700000    46.000000       1.000000     7.500000
# 25%    2013.000000         1.600000   123.000000   51000.000000     8.500000
# 50%    2018.000000         2.000000   152.000000  102230.000000     8.700000
# 75%    2021.000000         2.500000   211.000000  155314.000000     8.800000
# max    2023.000000         6.500000   800.000000  521208.000000     8.900000
#
#                Цена
# count  1.390000e+03
# mean   3.162654e+06
# std    3.823350e+06
# min    4.300000e+04
# 25%    1.095000e+06
# 50%    1.950000e+06
# 75%    3.782324e+06
# max    2.900000e+07

# %% [markdown]
# Ого! на дроме даже продают раритетные тачки!

# %%
df.loc[df['Год'] == 1950]
# Out:
#     Название   Год Топливо  Объем двигателя  Мощность Коробка передач  Привод  \
# 905  BMW 340  1950  бензин              2.0      55.0        механика  задний
#
#        Цвет   Пробег   Руль  Оценка Drom     Цена
# 905  черный  50000.0  левый          NaN  5600000

# %% [markdown]
# <img src="photо.jpg" width="800
#                             " height="340">

# %% [markdown]
# Посмотрим, сколько NaNов в наших столбцах

# %%
df1.isnull().sum()
# Out:
# Название             0
# Год                  0
# Топливо             15
# Объем двигателя     15
# Мощность            53
# Коробка передач     21
# Привод              23
# Цвет               141
# Пробег             289
# Руль                 9
# Оценка Drom        537
# Цена                 0
# dtype: int64

# %% [markdown]
# Глянем более наглядно на заполненность данных по столбцам

# %%
msno.matrix(df);

# %% [markdown]
# Видно, что больше всего пропусков встречаются в Оценке Drom, Пробеге и Цвете

# %% [markdown]
# ## Начнем с пробега

# %% [markdown]
# Есть подозрение, что пропуски в пробеге говорят о том, что там просто новые машинки, которые еще не успели поездить
#
# Проверим это по году выпуска? Будем считать, что право на нулевой пробег имеют только машины от 2022 года выпуска и младше

# %%
df1[(df1['Пробег'].isna()) & (df1['Год']<2022)]
# Out:
#                      Название   Год Топливо  Объем двигателя  Мощность  \
# 172           Volkswagen Polo  2019  бензин              1.6     110.0
# 175       Toyota Land Cruiser  2007  дизель              4.5     235.0
# 176     Mercedes-Benz S-Class  2015  бензин              3.0     333.0
# 178              Hyundai Getz  2008  бензин              1.4      97.0
# 179   Mercedes-Benz GLE Coupe  2015  бензин              3.0     333.0
# 342                   Audi Q7  2021  дизель              3.0     249.0
# 343     Mercedes-Benz S-Class  2021  бензин              3.0     367.0
# 384          Hyundai Santa Fe  2021  дизель              2.2     199.0
# 398     Mercedes-Benz S-Class  2021  дизель              2.9     249.0
# 400     Mercedes-Benz S-Class  2021  дизель              2.9     249.0
# 401     Mercedes-Benz S-Class  2021  дизель              2.9     249.0
# 470            Jeep Gladiator  2021  бензин              3.6     285.0
# 494   Mitsubishi Pajero Sport  2021  дизель              2.4     181.0
# 844               Kia Sorento  2002  дизель              2.5     145.0
# 846               Kia Sorento  2002  дизель              2.5     145.0
# 848         Nissan Pathfinder  2007  дизель              2.5     174.0
# 876              Cadillac XT4  2021     NaN              2.0       NaN
# 879     Chevrolet TrailBlazer  2021     NaN              1.3       NaN
# 898                Isuzu MU-X  2021  дизель              3.0     190.0
# 1044           Renault Kaptur  2021  бензин              1.6     114.0
# 1328              Lexus ES250  2021  бензин              2.5     200.0
#
#      Коробка передач    Привод         Цвет  Пробег   Руль  Оценка Drom  \
# 172             АКПП  передний          NaN     NaN  левый          8.6
# 175             АКПП       4WD          NaN     NaN  левый          NaN
# 176             АКПП       4WD          NaN     NaN  левый          NaN
# 178             АКПП  передний      красный     NaN  левый          8.3
# 179             АКПП       4WD      красный     NaN  левый          NaN
# 342             АКПП       4WD        синий     NaN  левый          NaN
# 343             АКПП       4WD  серебристый     NaN  левый          NaN
# 384            робот       4WD          NaN     NaN  левый          8.7
# 398             АКПП       4WD          NaN     NaN  левый          NaN
# 400             АКПП       4WD       черный     NaN  левый          NaN
# 401             АКПП       4WD       черный     NaN  левый          NaN
# 470             АКПП       4WD       черный     NaN  левый          NaN
# 494             АКПП       4WD       черный     NaN  левый          8.6
# 844             АКПП       4WD        серый     NaN  левый          8.6
# 846             АКПП       4WD          NaN     NaN  левый          8.6
# 848             АКПП       4WD          NaN     NaN  левый          8.6
# 876          автомат       NaN        синий     NaN  левый          NaN
# 879          автомат       NaN          NaN     NaN  левый          8.7
# 898          автомат       4WD          NaN     NaN  левый          NaN
# 1044        вариатор  передний          NaN     NaN  левый          8.7
# 1328            АКПП  передний          NaN     NaN  левый          NaN
#
#           Цена
# 172    1100000
# 175    2200000
# 176    2400000
# 178     425000
# 179    3400000
# 342   13610000
# 343   23148730
# 384    5357000
# 398   23740000
# 400   22072000
# 401   23634000
# 470    6990000
# 494    5309800
# 844     480000
# 846     530000
# 848     900000
# 876    7389058
# 879    2518872
# 898    6019000
# 1044   2439630
# 1328   7990000

# %% [markdown]
# Пробежимся по средним значениям для каждого года выпуска, присвоим нулевым пробегам эти значения соответственно

# %%
df.at [172, 'Пробег'] = df.loc[df['Год'] == 2019, 'Пробег'].mean()

# %%
df.at [342, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [384, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [398, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [470, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [494, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [876, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [879, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [898, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [1044, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()
df.at [1328, 'Пробег'] = df.loc[df['Год'] == 2021, 'Пробег'].mean()

# %%
df.at [175, 'Пробег'] = df.loc[df['Год'] == 2007, 'Пробег'].mean()
df.at [848, 'Пробег'] = df.loc[df['Год'] == 2007, 'Пробег'].mean()

# %%
df.at [176, 'Пробег'] = df.loc[df['Год'] == 2015, 'Пробег'].mean()

# %%
df.at [844, 'Пробег'] = df.loc[df['Год'] == 2002, 'Пробег'].mean()

# %%
df.at [178, 'Пробег'] = df.loc[df['Год'] == 2008, 'Пробег'].mean()

# %%
df[(df['Пробег'].isna()) & (df['Год']<2022)]
# Out:
#                     Название   Год Топливо  Объем двигателя  Мощность  \
# 179  Mercedes-Benz GLE Coupe  2015  бензин              3.0     333.0
# 343    Mercedes-Benz S-Class  2021  бензин              3.0     367.0
# 400    Mercedes-Benz S-Class  2021  дизель              2.9     249.0
# 401    Mercedes-Benz S-Class  2021  дизель              2.9     249.0
# 846              Kia Sorento  2002  дизель              2.5     145.0
#
#     Коробка передач Привод         Цвет  Пробег   Руль  Оценка Drom      Цена
# 179            АКПП    4WD      красный     NaN  левый          NaN   3400000
# 343            АКПП    4WD  серебристый     NaN  левый          NaN  23148730
# 400            АКПП    4WD       черный     NaN  левый          NaN  22072000
# 401            АКПП    4WD       черный     NaN  левый          NaN  23634000
# 846            АКПП    4WD          NaN     NaN  левый          8.6    530000

# %% [markdown]
# Остались только подозрительные строки дудоссеров, их удалим вообще

# %%
df.drop(axis=0, index=343, inplace=True)
df.drop(axis=0, index=400, inplace=True)
df.drop(axis=0, index=401, inplace=True)
df.drop(axis=0, index=846, inplace=True)

# %% [markdown]
# Ну вот, теперь все старые машины остались без нулевого пробега, сделаем новым пробег=0 вместо NaN

# %%
df['Пробег'].fillna(value=0, inplace=True)

# %% [markdown]
# ## Следующим большим вопросом стала Оценка Drom.

# %% [markdown]
# Там столько пропусков, что появляется желание ее удалить вообще... Однако, возможно, она нам еще пригодится...Заменим ее на среднее(8.602), тк по 10-балльной шкале, как выяснилось, минимум -- 7.5, а максимум -- 8.9, поэтому медиана(8.7) не так репрезентативна

# %%
df['Оценка Drom'].fillna(value=8.602, inplace=True)

# %% [markdown]
# ## Отлично! Теперь разберемся с мощностью

# %%
df[(df['Мощность'].isna())]
# Out:
#                    Название   Год Топливо  Объем двигателя  Мощность  \
# 130         Hyundai Solaris  2014  бензин              1.4       NaN
# 141             Kia Sorento  2012     NaN              2.4       NaN
# 147            Toyota Camry  2014     NaN              2.5       NaN
# 339            Kia Sportage  2010     NaN              2.0       NaN
# 344            Mazda Mazda6  2015  бензин              2.5       NaN
# 345       Volkswagen Tiguan  2017  бензин              1.4       NaN
# 346                 Kia Rio  2021  бензин              1.6       NaN
# 347                Haval F7  2020  бензин              2.0       NaN
# 348         SsangYong Kyron  2014  бензин              2.3       NaN
# 349            Kia Sportage  2016  бензин              2.0       NaN
# 350                 Kia Rio  2013  бензин              1.6       NaN
# 351             Nissan Juke  2012  бензин              1.6       NaN
# 352              Volvo XC70  2013  дизель              2.4       NaN
# 353        Citroen Berlingo  2012  бензин              1.6       NaN
# 355         Peugeot Partner  2008  бензин              1.4       NaN
# 356                Kia Ceed  2016  бензин              1.6       NaN
# 358                Kia Soul  2020  бензин              2.0       NaN
# 359                Kia Ceed  2013  бензин              1.6       NaN
# 360       Mitsubishi Pajero  2008  бензин              3.8       NaN
# 362       Volkswagen Tiguan  2013  бензин              1.4       NaN
# 367           Skoda Octavia  2017  бензин              1.8       NaN
# 368         Hyundai Solaris  2019  бензин              1.6       NaN
# 369             Skoda Rapid  2019  бензин              1.6       NaN
# 409           Changan UNI-K  2022  бензин              2.0       NaN
# 411            Changan CS95  2023  бензин              2.0       NaN
# 414            Changan CS95  2022  бензин              2.0       NaN
# 432       Toyota Highlander  2022  бензин              NaN       NaN
# 433       Toyota Highlander  2022  бензин              NaN       NaN
# 495            Changan CS95  2022  бензин              2.0       NaN
# 496            Changan CS95  2022  бензин              2.0       NaN
# 497            Changan CS95  2022  бензин              2.0       NaN
# 502            Changan CS95  2023  бензин              2.0       NaN
# 505           Changan UNI-K  2023  бензин              2.0       NaN
# 508            Changan CS95  2022  бензин              2.0       NaN
# 510            Changan CS95  2022  бензин              2.0       NaN
# 512           Changan UNI-K  2023  бензин              2.0       NaN
# 522       Toyota Highlander  2022  бензин              NaN       NaN
# 565               Лада 2102  1985  бензин              1.6       NaN
# 636       Volkswagen Tiguan  2019  дизель              2.0       NaN
# 637                 Audi Q8  2022  бензин              3.0       NaN
# 786         Volkswagen Golf  2011     NaN              1.6       NaN
# 789           Skoda Octavia  2011     NaN              1.4       NaN
# 876            Cadillac XT4  2021     NaN              2.0       NaN
# 879   Chevrolet TrailBlazer  2021     NaN              1.3       NaN
# 1136         Renault Duster  2015     NaN              1.5       NaN
# 1145             Ford Focus  2017     NaN              1.6       NaN
# 1297           Cadillac SRX  2011  бензин              3.0       NaN
# 1299      Nissan Pathfinder  2013  дизель              2.5       NaN
# 1301                Audi A4  2009  бензин              1.8       NaN
# 1302            Kia Sorento  2006  дизель              2.5       NaN
# 1304             Ford Focus  2018  бензин              1.6       NaN
# 1363            Kia Sorento  2022  бензин              2.5       NaN
# 1366      Mitsubishi Pajero  2019  бензин              3.8       NaN
#
#      Коробка передач    Привод         Цвет     Пробег   Руль  Оценка Drom  \
# 130              NaN  передний  серебристый   48950.00  левый        8.800
# 141          автомат       NaN       черный  205349.00  левый        8.600
# 147          автомат       NaN       черный  234094.00  левый        8.800
# 339         механика       NaN        серый  117600.00  левый        8.700
# 344              NaN  передний        белый  164036.00  левый        8.900
# 345              NaN  передний      бежевый  105298.00  левый        8.602
# 346              NaN  передний       черный   53384.00  левый        8.700
# 347              NaN       4WD        синий   41009.00  левый        8.602
# 348              NaN       4WD        белый  166868.00  левый        8.100
# 349              NaN  передний        серый  142294.00  левый        8.700
# 350              NaN  передний       черный  178421.00  левый        8.700
# 351          автомат       4WD        белый  173486.00  левый        8.800
# 352              NaN       4WD       черный  247611.00  левый        8.602
# 353         механика  передний        белый  262911.00  левый        8.000
# 355         механика  передний        белый  460666.00  левый        8.000
# 356              NaN  передний       черный  131773.00  левый        8.800
# 358              NaN  передний        белый   26058.00  левый        8.800
# 359              NaN  передний   коричневый  204180.00  левый        8.800
# 360              NaN       4WD       черный  164507.00  левый        8.400
# 362              NaN  передний       черный  102000.00  левый        8.602
# 367              NaN  передний  серебристый  107017.00  левый        8.800
# 368              NaN  передний        белый   71822.00  левый        8.800
# 369              NaN  передний        синий  115010.00  левый        8.602
# 409          автомат       NaN        белый       0.00  левый        8.602
# 411          автомат       NaN        серый       0.00  левый        8.602
# 414          автомат       NaN       черный       0.00  левый        8.602
# 432          автомат       4WD          NaN       0.00  левый        8.602
# 433          автомат       4WD  серебристый       0.00  левый        8.602
# 495          автомат       NaN        белый       0.00  левый        8.602
# 496          автомат       NaN        серый       0.00  левый        8.602
# 497          автомат       NaN        белый       0.00  левый        8.602
# 502          автомат       NaN       черный       0.00  левый        8.602
# 505          автомат       NaN        белый       0.00  левый        8.602
# 508          автомат       NaN        белый       0.00  левый        8.602
# 510          автомат       NaN       черный       0.00  левый        8.602
# 512          автомат       NaN        серый       0.00  левый        8.602
# 522          автомат       4WD        белый       0.00  левый        8.602
# 565         механика    задний      бежевый   99999.00  левый        8.602
# 636          автомат       4WD        белый   43186.00  левый        8.602
# 637          автомат       4WD        белый    9374.00  левый        8.800
# 786          автомат       NaN        серый  124021.00  левый        8.700
# 789         механика       NaN        серый  238627.00  левый        8.800
# 876          автомат       NaN        синий   33682.25  левый        8.602
# 879          автомат       NaN          NaN   33682.25  левый        8.700
# 1136        механика       NaN      зеленый  109718.00  левый        8.300
# 1145        механика       NaN        белый   80151.00  левый        8.500
# 1297         автомат       4WD       черный  131407.00  левый        8.900
# 1299             NaN       4WD        серый  231651.00  левый        8.600
# 1301         автомат  передний       черный  288790.00  левый        8.800
# 1302             NaN       4WD  серебристый  124292.00  левый        8.600
# 1304             NaN  передний        белый   85703.00  левый        8.500
# 1363         автомат  передний        белый     167.00  левый        8.600
# 1366         автомат       4WD        белый      36.00  левый        8.400
#
#           Цена
# 130     983000
# 141    1378000
# 147    1448000
# 339     839000
# 344    1520000
# 345    1839000
# 346    1550000
# 347    2100000
# 348     950000
# 349    1650000
# 350     810000
# 351     870000
# 352    1700000
# 353     710000
# 355     310000
# 356    1380000
# 358    2150540
# 359    1200000
# 360    1500000
# 362    1050000
# 367    1850000
# 368    1590000
# 369    1480000
# 409    3939000
# 411    4290000
# 414    4315449
# 432    6990000
# 433    7790000
# 495    4290000
# 496    4290000
# 497    4308957
# 502    4290000
# 505    3939000
# 508    4291548
# 510    4290000
# 512    3939000
# 522    6990000
# 565      75000
# 636    3449000
# 637   11650000
# 786     779000
# 789     649000
# 876    7389058
# 879    2518872
# 1136   1088000
# 1145   1198000
# 1297   1250000
# 1299   1592000
# 1301    800000
# 1302    790000
# 1304   1230000
# 1363   4800000
# 1366   3800000

# %%
df.drop(axis=0, index=359, inplace=True)
df.drop(axis=0, index=414, inplace=True)
df.drop(axis=0, index=433, inplace=True)
df.drop(axis=0, index=497, inplace=True)
df.drop(axis=0, index=496, inplace=True)
df.drop(axis=0, index=502, inplace=True)
df.drop(axis=0, index=505, inplace=True)
df.drop(axis=0, index=508, inplace=True)
df.drop(axis=0, index=510, inplace=True)
df.drop(axis=0, index=512, inplace=True)
df.drop(axis=0, index=522, inplace=True)
df.drop(axis=0, index=879, inplace=True)
df.drop(axis=0, index=876, inplace=True)
df.drop(axis=0, index=495, inplace=True)
df.drop(axis=0, index=344, inplace=True)
df.drop(axis=0, index=358, inplace=True)

# %% [markdown]
# Здесь опять на лицо куча дудос-строк, избавимся от них

# %%
df[(df['Мощность'].isna())]
# Out:
#                Название   Год Топливо  Объем двигателя  Мощность  \
# 130     Hyundai Solaris  2014  бензин              1.4       NaN
# 141         Kia Sorento  2012     NaN              2.4       NaN
# 147        Toyota Camry  2014     NaN              2.5       NaN
# 339        Kia Sportage  2010     NaN              2.0       NaN
# 345   Volkswagen Tiguan  2017  бензин              1.4       NaN
# 346             Kia Rio  2021  бензин              1.6       NaN
# 347            Haval F7  2020  бензин              2.0       NaN
# 348     SsangYong Kyron  2014  бензин              2.3       NaN
# 349        Kia Sportage  2016  бензин              2.0       NaN
# 350             Kia Rio  2013  бензин              1.6       NaN
# 351         Nissan Juke  2012  бензин              1.6       NaN
# 352          Volvo XC70  2013  дизель              2.4       NaN
# 353    Citroen Berlingo  2012  бензин              1.6       NaN
# 355     Peugeot Partner  2008  бензин              1.4       NaN
# 356            Kia Ceed  2016  бензин              1.6       NaN
# 360   Mitsubishi Pajero  2008  бензин              3.8       NaN
# 362   Volkswagen Tiguan  2013  бензин              1.4       NaN
# 367       Skoda Octavia  2017  бензин              1.8       NaN
# 368     Hyundai Solaris  2019  бензин              1.6       NaN
# 369         Skoda Rapid  2019  бензин              1.6       NaN
# 409       Changan UNI-K  2022  бензин              2.0       NaN
# 411        Changan CS95  2023  бензин              2.0       NaN
# 432   Toyota Highlander  2022  бензин              NaN       NaN
# 565           Лада 2102  1985  бензин              1.6       NaN
# 636   Volkswagen Tiguan  2019  дизель              2.0       NaN
# 637             Audi Q8  2022  бензин              3.0       NaN
# 786     Volkswagen Golf  2011     NaN              1.6       NaN
# 789       Skoda Octavia  2011     NaN              1.4       NaN
# 1136     Renault Duster  2015     NaN              1.5       NaN
# 1145         Ford Focus  2017     NaN              1.6       NaN
# 1297       Cadillac SRX  2011  бензин              3.0       NaN
# 1299  Nissan Pathfinder  2013  дизель              2.5       NaN
# 1301            Audi A4  2009  бензин              1.8       NaN
# 1302        Kia Sorento  2006  дизель              2.5       NaN
# 1304         Ford Focus  2018  бензин              1.6       NaN
# 1363        Kia Sorento  2022  бензин              2.5       NaN
# 1366  Mitsubishi Pajero  2019  бензин              3.8       NaN
#
#      Коробка передач    Привод         Цвет    Пробег   Руль  Оценка Drom  \
# 130              NaN  передний  серебристый   48950.0  левый        8.800
# 141          автомат       NaN       черный  205349.0  левый        8.600
# 147          автомат       NaN       черный  234094.0  левый        8.800
# 339         механика       NaN        серый  117600.0  левый        8.700
# 345              NaN  передний      бежевый  105298.0  левый        8.602
# 346              NaN  передний       черный   53384.0  левый        8.700
# 347              NaN       4WD        синий   41009.0  левый        8.602
# 348              NaN       4WD        белый  166868.0  левый        8.100
# 349              NaN  передний        серый  142294.0  левый        8.700
# 350              NaN  передний       черный  178421.0  левый        8.700
# 351          автомат       4WD        белый  173486.0  левый        8.800
# 352              NaN       4WD       черный  247611.0  левый        8.602
# 353         механика  передний        белый  262911.0  левый        8.000
# 355         механика  передний        белый  460666.0  левый        8.000
# 356              NaN  передний       черный  131773.0  левый        8.800
# 360              NaN       4WD       черный  164507.0  левый        8.400
# 362              NaN  передний       черный  102000.0  левый        8.602
# 367              NaN  передний  серебристый  107017.0  левый        8.800
# 368              NaN  передний        белый   71822.0  левый        8.800
# 369              NaN  передний        синий  115010.0  левый        8.602
# 409          автомат       NaN        белый       0.0  левый        8.602
# 411          автомат       NaN        серый       0.0  левый        8.602
# 432          автомат       4WD          NaN       0.0  левый        8.602
# 565         механика    задний      бежевый   99999.0  левый        8.602
# 636          автомат       4WD        белый   43186.0  левый        8.602
# 637          автомат       4WD        белый    9374.0  левый        8.800
# 786          автомат       NaN        серый  124021.0  левый        8.700
# 789         механика       NaN        серый  238627.0  левый        8.800
# 1136        механика       NaN      зеленый  109718.0  левый        8.300
# 1145        механика       NaN        белый   80151.0  левый        8.500
# 1297         автомат       4WD       черный  131407.0  левый        8.900
# 1299             NaN       4WD        серый  231651.0  левый        8.600
# 1301         автомат  передний       черный  288790.0  левый        8.800
# 1302             NaN       4WD  серебристый  124292.0  левый        8.600
# 1304             NaN  передний        белый   85703.0  левый        8.500
# 1363         автомат  передний        белый     167.0  левый        8.600
# 1366         автомат       4WD        белый      36.0  левый        8.400
#
#           Цена
# 130     983000
# 141    1378000
# 147    1448000
# 339     839000
# 345    1839000
# 346    1550000
# 347    2100000
# 348     950000
# 349    1650000
# 350     810000
# 351     870000
# 352    1700000
# 353     710000
# 355     310000
# 356    1380000
# 360    1500000
# 362    1050000
# 367    1850000
# 368    1590000
# 369    1480000
# 409    3939000
# 411    4290000
# 432    6990000
# 565      75000
# 636    3449000
# 637   11650000
# 786     779000
# 789     649000
# 1136   1088000
# 1145   1198000
# 1297   1250000
# 1299   1592000
# 1301    800000
# 1302    790000
# 1304   1230000
# 1363   4800000
# 1366   3800000

# %% [markdown]
# Кажется логичным NaNовую мощность у Hyundai Solaris заменить на 123

# %%
df[(df['Мощность']!=0) & (df['Название']=='Hyundai Solaris')]
# Out:
#              Название   Год Топливо  Объем двигателя  Мощность  \
# 130   Hyundai Solaris  2014  бензин              1.4       NaN
# 205   Hyundai Solaris  2016  бензин              1.6     123.0
# 226   Hyundai Solaris  2017  бензин              1.6     123.0
# 237   Hyundai Solaris  2019  бензин              1.6     123.0
# 249   Hyundai Solaris  2015  бензин              1.6     123.0
# 293   Hyundai Solaris  2016  бензин              1.6     123.0
# 303   Hyundai Solaris  2020  бензин              1.6     123.0
# 338   Hyundai Solaris  2018  бензин              1.6     123.0
# 368   Hyundai Solaris  2019  бензин              1.6       NaN
# 504   Hyundai Solaris  2015  бензин              1.6     123.0
# 602   Hyundai Solaris  2018  бензин              1.4     100.0
# 638   Hyundai Solaris  2018  бензин              1.4     100.0
# 667   Hyundai Solaris  2016  бензин              1.6     123.0
# 711   Hyundai Solaris  2019  бензин              1.6     123.0
# 768   Hyundai Solaris  2015  бензин              1.6     123.0
# 1070  Hyundai Solaris  2011  бензин              1.6     123.0
# 1170  Hyundai Solaris  2015  бензин              1.6     123.0
# 1247  Hyundai Solaris  2021  бензин              1.6     123.0
# 1260  Hyundai Solaris  2019  бензин              1.6     123.0
# 1279  Hyundai Solaris  2021  бензин              1.6     123.0
#
#      Коробка передач    Привод         Цвет    Пробег   Руль  Оценка Drom  \
# 130              NaN  передний  серебристый   48950.0  левый          8.8
# 205             АКПП  передний      бежевый   33502.0  левый          8.8
# 226             АКПП  передний        белый  142515.0  левый          8.8
# 237             АКПП  передний        белый   82930.0  левый          8.8
# 249             АКПП  передний       черный  174369.0  левый          8.8
# 293             АКПП  передний          NaN   98556.0  левый          8.8
# 303             АКПП  передний          NaN   94585.0  левый          8.8
# 338             АКПП  передний        белый   67405.0  левый          8.8
# 368              NaN  передний        белый   71822.0  левый          8.8
# 504             АКПП  передний        белый  123303.0  левый          8.8
# 602             АКПП  передний        белый   85315.0  левый          8.8
# 638             АКПП  передний        белый  104459.0  левый          8.8
# 667             АКПП  передний        синий   54535.0  левый          8.8
# 711             АКПП  передний        серый  255700.0  левый          8.8
# 768         механика  передний        белый  257158.0  левый          8.8
# 1070        механика  передний      красный  118972.0  левый          8.8
# 1170            АКПП  передний   коричневый  128930.0  левый          8.8
# 1247            АКПП  передний       черный   28000.0  левый          8.8
# 1260            АКПП  передний        белый  103049.0  левый          8.8
# 1279            АКПП  передний        серый   67380.0  левый          8.8
#
#          Цена
# 130    983000
# 205   1267000
# 226   1066000
# 237   1453000
# 249    900000
# 293   1015000
# 303   1445000
# 338   1428000
# 368   1590000
# 504    999000
# 602   1365000
# 638    870000
# 667   1094000
# 711   1153000
# 768    551000
# 1070   710000
# 1170  1049700
# 1247  1349000
# 1260  1310000
# 1279  1790000

# %%
df.at [130, 'Мощность'] = 123.0
df.at [368, 'Мощность'] = 123.0

# %% [markdown]
# Проделываем то же для остальных марок

# %%
df.loc[df['Название'] == 'Kia Sorento', 'Мощность'].median()
# Out:
# 199.0

# %% [markdown]
# Заменим NaNовую мощность у Kia Sorento на медианную, тк она более выбросоустойчива, чем средняя, хотя они и очень близки

# %%
df.at [141, 'Мощность'] = df.loc[df['Название'] == 'Kia Sorento', 'Мощность'].median()
df.at [1302, 'Мощность'] = df.loc[df['Название'] == 'Kia Sorento', 'Мощность'].median()
df.at [1363, 'Мощность'] = df.loc[df['Название'] == 'Kia Sorento', 'Мощность'].median()

# %%
df.at [345, 'Мощность'] = df.loc[df['Название'] == 'Volkswagen Tiguan', 'Мощность'].median()
df.at [362, 'Мощность'] = df.loc[df['Название'] == 'Volkswagen Tiguan', 'Мощность'].median()
df.at [636, 'Мощность'] = df.loc[df['Название'] == 'Volkswagen Tiguan', 'Мощность'].median()

# %%
df.at [147, 'Мощность'] = df.loc[df['Название'] == 'Toyota Camry', 'Мощность'].median()

# %%
df.at [339, 'Мощность'] = df.loc[df['Название'] == 'Kia Sportage', 'Мощность'].median()
df.at [349, 'Мощность'] = df.loc[df['Название'] == 'Kia Sportage', 'Мощность'].median()

# %%
df.at [346, 'Мощность'] = df.loc[df['Название'] == 'Kia Rio', 'Мощность'].median()
df.at [350, 'Мощность'] = df.loc[df['Название'] == 'Kia Rio', 'Мощность'].median()

# %%
df.at [360, 'Мощность'] = df.loc[df['Название'] == 'Mitsubishi Pajero', 'Мощность'].median()
df.at [1366, 'Мощность'] = df.loc[df['Название'] == 'Mitsubishi Pajero', 'Мощность'].median()

# %%
df.at [347, 'Мощность'] = df.loc[df['Название'] == 'Haval F7', 'Мощность'].median()

# %%
df.at [348, 'Мощность'] = df.loc[df['Название'] == 'SsangYong Kyron', 'Мощность'].median()

# %%
df.at [351, 'Мощность'] = df.loc[df['Название'] == 'Nissan Juke', 'Мощность'].median()

# %% [markdown]
# А вот Volvo XC70 оказалась одной единственной машинкой этой марки, так что пришлось поискать в интернете, какая у нее могла бы быть мощность в теории

# %%
df.at [352, 'Мощность'] = 215

# %%
df.at [353, 'Мощность'] = df.loc[df['Название'] == 'Citroen Berlingo', 'Мощность'].median()

# %% [markdown]
# Peugeot Partner тоже найдем в интернетах

# %%
df.at [355, 'Мощность'] = 75

# %%
df.at [356, 'Мощность'] = df.loc[df['Название'] == 'Kia Ceed', 'Мощность'].median()

# %%
df.at [367, 'Мощность'] = df.loc[df['Название'] == 'Skoda Octavia', 'Мощность'].median()
df.at [789, 'Мощность'] = df.loc[df['Название'] == 'Skoda Octavia', 'Мощность'].median()

# %%
df.at [369, 'Мощность'] = df.loc[df['Название'] == 'Skoda Rapid', 'Мощность'].median()

# %%
df.at [409, 'Мощность'] = df.loc[df['Название'] == 'Changan UNI-K', 'Мощность'].median()

# %% [markdown]
# Changan CS95 тоже найдем в интернетах

# %%
df.at [411, 'Мощность'] = 233

# %% [markdown]
# Toyota Highlander	2022	бензин	тоже

# %%
df.at [432, 'Мощность'] = 244

# %% [markdown]
# Лада 2102 тоже :)

# %%
df.at [565, 'Мощность'] = 64

# %%
df.at [1145, 'Мощность'] = df.loc[df['Название'] == 'Ford Focus', 'Мощность'].median()
df.at [1304, 'Мощность'] = df.loc[df['Название'] == 'Ford Focus', 'Мощность'].median()

# %%
df.at [1299, 'Мощность'] = df.loc[df['Название'] == 'Nissan Pathfinder', 'Мощность'].median()

# %% [markdown]
# Audi Q8 тоже :)

# %%
df.at [637, 'Мощность'] = 340

# %%
df.at [786, 'Мощность'] = df.loc[df['Название'] == 'Volkswagen Golf', 'Мощность'].median()

# %%
df.at [1136, 'Мощность'] = df.loc[df['Название'] == 'Renault Duster', 'Мощность'].median()

# %% [markdown]
# Cadillac SRX тоже :)

# %%
df.at [1297, 'Мощность'] = 270

# %%
df.at [1301, 'Мощность'] = df.loc[df['Название'] == 'Audi A4', 'Мощность'].median()

# %%
# Все вышеперечисленные марки автомобилей мы проверяли через такую штучку, чтобы убедиться, что медиана существует и она репрезентативна
df[(df['Мощность']!=0) & (df['Название']=='...')]
# Out:
# Empty DataFrame
# Columns: [Название, Год, Топливо, Объем двигателя, Мощность, Коробка передач, Привод, Цвет, Пробег, Руль, Оценка Drom, Цена]
# Index: []

# %% [markdown]
# # Что ж, теперь разберемся с объемами двигателей

# %%
df[(df['Объем двигателя'].isnull())]
# Out:
#                    Название   Год  Топливо  Объем двигателя  Мощность  \
# 24        Mercedes-Benz EQV  2021  электро              NaN     204.0
# 83               Rivian R1T  2022  электро              NaN     760.0
# 94            Tesla Model X  2022  электро              NaN     670.0
# 366                BYD Yuan  2019  электро              NaN     163.0
# 432       Toyota Highlander  2022   бензин              NaN     244.0
# 847             Nissan Leaf  2016  электро              NaN     109.0
# 948           Evolute i-Joy  2022  электро              NaN     163.0
# 1005            Nissan Leaf  2014  электро              NaN     109.0
# 1075                 BMW i7  2022  электро              NaN     544.0
# 1083                 BMW iX  2022  электро              NaN     523.0
# 1201  Volkswagen ID.6 Crozz  2022  электро              NaN     204.0
# 1202        Volkswagen ID.4  2023  электро              NaN     313.0
# 1203        Volkswagen ID.4  2023  электро              NaN     313.0
#
#      Коробка передач    Привод     Цвет   Пробег    Руль  Оценка Drom  \
# 24              АКПП  передний   черный  19690.0   левый        8.602
# 83              АКПП       4WD  зеленый      0.0   левый        8.602
# 94           автомат       4WD    белый      0.0   левый        8.400
# 366          автомат  передний    белый  55000.0   левый        8.602
# 432          автомат       4WD      NaN      0.0   левый        8.602
# 847             АКПП  передний    белый  64000.0  правый        8.602
# 948             АКПП  передний   черный      0.0   левый        8.602
# 1005            АКПП  передний   черный  70000.0  правый        8.602
# 1075         автомат       4WD   черный   4200.0   левый        8.602
# 1083            АКПП       4WD   черный  10800.0   левый        8.602
# 1201            АКПП    задний    синий      0.0   левый        8.602
# 1202         автомат       4WD    синий      0.0   левый        8.602
# 1203         автомат       4WD    белый      0.0   левый        8.602
#
#           Цена
# 24     7890000
# 83    15990000
# 94    11450000
# 366    2100000
# 432    6990000
# 847    1019000
# 948    3490000
# 1005    800000
# 1075  26690000
# 1083  10900000
# 1201   4850000
# 1202   5400000
# 1203   5400000

# %% [markdown]
# Здесь очевидно собраны те машины, у которых двигатель заправляется не топливом, а электричеством. Поэтому их двигатель вообще не имеет объема. Единственным исключением стала Toyota Highlander на бензине, ее объем мы проверим в интернете. У электрокаров заменим объем на нули

# %%
df.at [432, 'Объем двигателя'] = 3.5

# %%
df['Объем двигателя'].fillna(value=0, inplace=True)

# %% [markdown]
# ## Займемся топливом

# %%
df[(df['Топливо'].isnull())]
# Out:
#              Название   Год Топливо  Объем двигателя  Мощность  \
# 141       Kia Sorento  2012     NaN              2.4     199.0
# 147      Toyota Camry  2014     NaN              2.5     181.0
# 339      Kia Sportage  2010     NaN              2.0     150.0
# 786   Volkswagen Golf  2011     NaN              1.6     122.0
# 789     Skoda Octavia  2011     NaN              1.4     152.0
# 831        Voyah Free  2023     NaN              1.5     693.0
# 833        Voyah Free  2023     NaN              1.5     693.0
# 834        Voyah Free  2023     NaN              1.5     693.0
# 838        Voyah Free  2023     NaN              1.5     693.0
# 839        Voyah Free  2023     NaN              1.5     693.0
# 845       Voyah Dream  2022     NaN              1.5     395.0
# 1136   Renault Duster  2015     NaN              1.5     114.0
# 1145       Ford Focus  2017     NaN              1.6     110.0
#
#      Коробка передач Привод     Цвет    Пробег   Руль  Оценка Drom     Цена
# 141          автомат    NaN   черный  205349.0  левый        8.600  1378000
# 147          автомат    NaN   черный  234094.0  левый        8.800  1448000
# 339         механика    NaN    серый  117600.0  левый        8.700   839000
# 786          автомат    NaN    серый  124021.0  левый        8.700   779000
# 789         механика    NaN    серый  238627.0  левый        8.800   649000
# 831          автомат    4WD  голубой       0.0  левый        8.602  7490000
# 833          автомат    4WD   черный       0.0  левый        8.602  7490000
# 834          автомат    4WD    синий       0.0  левый        8.602  7490000
# 838          автомат    4WD    серый       0.0  левый        8.602  7490000
# 839          автомат    4WD    белый       0.0  левый        8.602  7490000
# 845          автомат    4WD   черный       0.0  левый        8.602  8290000
# 1136        механика    NaN  зеленый  109718.0  левый        8.300  1088000
# 1145        механика    NaN    белый   80151.0  левый        8.500  1198000

# %% [markdown]
# По статистике, более 80% автомобилей ездят на бензине. Поэтому вряд ли мы ошибемся, если заменим NaNы на "бензин"

# %%
df['Топливо'].fillna(value='бензин', inplace=True)

# %% [markdown]
# ## Посмотрим на NaNы в коробке передач

# %%
df[(df['Коробка передач'].isnull())]
# Out:
#                      Название   Год Топливо  Объем двигателя  Мощность  \
# 130           Hyundai Solaris  2014  бензин              1.4     123.0
# 345         Volkswagen Tiguan  2017  бензин              1.4     150.0
# 346                   Kia Rio  2021  бензин              1.6     123.0
# 347                  Haval F7  2020  бензин              2.0     190.0
# 348           SsangYong Kyron  2014  бензин              2.3     141.0
# 349              Kia Sportage  2016  бензин              2.0     150.0
# 350                   Kia Rio  2013  бензин              1.6     123.0
# 352                Volvo XC70  2013  дизель              2.4     215.0
# 356                  Kia Ceed  2016  бензин              1.6     128.0
# 360         Mitsubishi Pajero  2008  бензин              3.8     174.0
# 362         Volkswagen Tiguan  2013  бензин              1.4     150.0
# 367             Skoda Octavia  2017  бензин              1.8     152.0
# 368           Hyundai Solaris  2019  бензин              1.6     123.0
# 369               Skoda Rapid  2019  бензин              1.6     110.0
# 1275  Mercedes-Benz CLA-Class  2019  бензин              2.0     150.0
# 1299        Nissan Pathfinder  2013  дизель              2.5     211.5
# 1302              Kia Sorento  2006  дизель              2.5     199.0
# 1304               Ford Focus  2018  бензин              1.6     110.0
#
#      Коробка передач    Привод         Цвет    Пробег   Руль  Оценка Drom  \
# 130              NaN  передний  серебристый   48950.0  левый        8.800
# 345              NaN  передний      бежевый  105298.0  левый        8.602
# 346              NaN  передний       черный   53384.0  левый        8.700
# 347              NaN       4WD        синий   41009.0  левый        8.602
# 348              NaN       4WD        белый  166868.0  левый        8.100
# 349              NaN  передний        серый  142294.0  левый        8.700
# 350              NaN  передний       черный  178421.0  левый        8.700
# 352              NaN       4WD       черный  247611.0  левый        8.602
# 356              NaN  передний       черный  131773.0  левый        8.800
# 360              NaN       4WD       черный  164507.0  левый        8.400
# 362              NaN  передний       черный  102000.0  левый        8.602
# 367              NaN  передний  серебристый  107017.0  левый        8.800
# 368              NaN  передний        белый   71822.0  левый        8.800
# 369              NaN  передний        синий  115010.0  левый        8.602
# 1275             NaN       NaN          NaN   68000.0  левый        8.602
# 1299             NaN       4WD        серый  231651.0  левый        8.600
# 1302             NaN       4WD  серебристый  124292.0  левый        8.600
# 1304             NaN  передний        белый   85703.0  левый        8.500
#
#          Цена
# 130    983000
# 345   1839000
# 346   1550000
# 347   2100000
# 348    950000
# 349   1650000
# 350    810000
# 352   1700000
# 356   1380000
# 360   1500000
# 362   1050000
# 367   1850000
# 368   1590000
# 369   1480000
# 1275  2990000
# 1299  1592000
# 1302   790000
# 1304  1230000

# %% [markdown]
# # Update

# %% [markdown]
# > ##### Изначально было так: "Было принято решение всем иномаркам старше 2010 года приписать автоматическую коробку передач, тк это очень даже соответсвует реалиям на рынке"
#
# > #### Однако после комментария, полученного на чекпойнте, мы решили более корректно заменить наны в этом случае. А именно: заменить на автомат не все наны подряд, а примерно пропорционально ситуации на рынке. Инфромацию мы погуглили и вот, что нашли:
#
# >"В агентстве Автостат подсчитали, что по итогам первых девяти месяцев 2021 года доля машин с автоматическими трансмиссиями (включая вариаторы и «роботы») на российском рынке достигла 66% (771 тысяча машин).
#
# >"...Как оказалось, автомобили на "механике" составляют 36% от общего числа представленных в сервисе автомобилей."

# %% [markdown]
# #### Из 18 нановых строк сделаем 11 автоматом и 7 механикой. Причем пусть механикой будут наиболее старые тачки.

# %%
#df['Коробка передач'].fillna(value='автомат', inplace=True)
#df['Коробка передач'].fillna(value='механика', inplace=True)
# старый код

# %%
df.at [1302, 'Коробка передач'] = 'механика' #2006
df.at [360, 'Коробка передач'] = 'механика'   #2008
df.at [350, 'Коробка передач'] = 'механика'   #2013
df.at [352, 'Коробка передач'] = 'механика'   #2013
df.at [362, 'Коробка передач'] = 'механика'   #2013
df.at [1299, 'Коробка передач'] = 'механика' #2013 
df.at [130, 'Коробка передач'] = 'механика'   #2014

# %%
df['Коробка передач'].fillna(value='автомат', inplace=True)

# %% [markdown]
# А еще АКПП это и есть автомат, так что исправим это

# %%
df.loc[df['Коробка передач'] == 'АКПП', 'Коробка передач'] = 'автомат'

# %% [markdown]
# ## А как там рули?

# %%
df[(df['Руль'].isnull())]
# Out:
#               Название   Год Топливо  Объем двигателя  Мощность  \
# 134          Лада 2105  1997  бензин              1.5      71.0
# 142          Лада 2110  1999  бензин              1.5      70.0
# 194   Volkswagen Atlas  2020  бензин              2.0     235.0
# 543          Лада 2107  2008  бензин              1.6      73.0
# 570    Chevrolet Lanos  2005  бензин              1.5      86.0
# 866        Lifan Smily  2011  бензин              1.3      89.0
# 1106         Лада 2107  1987  бензин              1.5      71.0
# 1224         Лада 2107  2011  бензин              1.6      74.0
# 1327      Infiniti M25  2012  бензин              2.5     222.0
#
#      Коробка передач    Привод     Цвет    Пробег Руль  Оценка Drom     Цена
# 134         механика    задний  зеленый   27000.0  NaN        8.602    68000
# 142         механика  передний  голубой   29131.0  NaN        7.600   500000
# 194          автомат       4WD   черный   26470.0  NaN        8.602  4200000
# 543         механика    задний  зеленый   90681.0  NaN        7.600   110000
# 570         механика  передний   черный  150000.0  NaN        7.500   150000
# 866         механика  передний  красный  150000.0  NaN        8.100   130000
# 1106        механика    задний  бежевый  200000.0  NaN        7.600    43000
# 1224        механика    задний      NaN   58000.0  NaN        7.600   179000
# 1327         автомат    задний   черный  147386.0  NaN        8.602  1800000

# %% [markdown]
# # Update

# %% [markdown]
# > ##### Изначально было так: "Очевидно, все праворульные машины скорее всего производят Японии и Великобритании. А в списке выше таких нет, поэтому можем по умолчанию исправить рули на левые"
#
# > Однако проверяющий не согласился с нашей теорией, так что проверим это все ручками в интернете.
#
# > Результат нашего научного ресёрча: ***(барабанная дробь)***
# 1. Лада 2105 - руль слева
# 2. Лада 2110 - руль слева
# 3. Лада 2107 - руль слева
# 4. Volkswagen Atlas - руль слева
# 5. Chevrolet Lanos - руль слева
# 6. Lifan Smily - руль слева
# 7. Infiniti M25 - может быть слева и справа, но конкретно это объявление на данный момент уже снято с продажи... Поэтому мы уже никогда не узнаем, какой там был руль. Но у всех Infiniti M25 2012 года той же комплектации руль находится слева
#
# > Поэтому считаем совершенно правомерным заменить все руль на левые

# %%
df['Руль'].fillna(value='левый', inplace=True)

# %% [markdown]
# ## Привод

# %%
df[(df['Привод'].isnull())]
# Out:
#                      Название   Год Топливо  Объем двигателя  Мощность  \
# 141               Kia Sorento  2012  бензин              2.4     199.0
# 147              Toyota Camry  2014  бензин              2.5     181.0
# 193               УАЗ Буханка  2023  бензин              2.7     112.0
# 339              Kia Sportage  2010  бензин              2.0     150.0
# 409             Changan UNI-K  2022  бензин              2.0     226.0
# 411              Changan CS95  2023  бензин              2.0     233.0
# 786           Volkswagen Golf  2011  бензин              1.6     122.0
# 789             Skoda Octavia  2011  бензин              1.4     152.0
# 797               Skoda Rapid  2015  бензин              1.6     110.0
# 1136           Renault Duster  2015  бензин              1.5     114.0
# 1145               Ford Focus  2017  бензин              1.6     110.0
# 1275  Mercedes-Benz CLA-Class  2019  бензин              2.0     150.0
#
#      Коробка передач Привод        Цвет    Пробег   Руль  Оценка Drom     Цена
# 141          автомат    NaN      черный  205349.0  левый        8.600  1378000
# 147          автомат    NaN      черный  234094.0  левый        8.800  1448000
# 193         механика    NaN         NaN       0.0  левый        8.602  1333000
# 339         механика    NaN       серый  117600.0  левый        8.700   839000
# 409          автомат    NaN       белый       0.0  левый        8.602  3939000
# 411          автомат    NaN       серый       0.0  левый        8.602  4290000
# 786          автомат    NaN       серый  124021.0  левый        8.700   779000
# 789         механика    NaN       серый  238627.0  левый        8.800   649000
# 797          автомат    NaN  коричневый  204710.0  левый        8.602   600000
# 1136        механика    NaN     зеленый  109718.0  левый        8.300  1088000
# 1145        механика    NaN       белый   80151.0  левый        8.500  1198000
# 1275         автомат    NaN         NaN   68000.0  левый        8.602  2990000

# %% [markdown]
# Заменим NaNовые приводы на самый популярный по определению тип привода

# %%
df['Привод'].fillna(value='передний', inplace=True)

# %% [markdown]
# ## Цвет

# %%
df[(df['Цвет'].isnull())]
# Out:
#                           Название   Год Топливо  Объем двигателя  Мощность  \
# 139               Лада Нива Тревел  2023  бензин              1.7      80.0
# 158   Land Rover Range Rover Sport  2014  дизель              3.0     249.0
# 172                Volkswagen Polo  2019  бензин              1.6     110.0
# 175            Toyota Land Cruiser  2007  дизель              4.5     235.0
# 176          Mercedes-Benz S-Class  2015  бензин              3.0     333.0
# ...                            ...   ...     ...              ...       ...
# 1340                   Genesis G70  2019  бензин              2.0     197.0
# 1341                Nissan Qashqai  2019  бензин              2.0     144.0
# 1343                       Audi Q3  2016  бензин              2.0     180.0
# 1351                  BMW 5-Series  2021  дизель              2.0     190.0
# 1368                  BMW 3-Series  2008  бензин              2.0     156.0
#
#      Коробка передач    Привод Цвет         Пробег   Руль  Оценка Drom  \
# 139         механика       4WD  NaN       0.000000  левый        8.602
# 158          автомат       4WD  NaN  173000.000000  левый        8.602
# 172          автомат  передний  NaN   74205.109827  левый        8.600
# 175          автомат       4WD  NaN  232020.300000  левый        8.602
# 176          автомат       4WD  NaN  137364.609756  левый        8.602
# ...              ...       ...  ...            ...    ...          ...
# 1340         автомат       4WD  NaN   88652.000000  левый        8.900
# 1341        вариатор  передний  NaN   88798.000000  левый        8.600
# 1343           робот       4WD  NaN  115000.000000  левый        8.602
# 1351         автомат       4WD  NaN   36498.000000  левый        8.900
# 1368         автомат    задний  NaN  240000.000000  левый        8.800
#
#          Цена
# 139   1277000
# 158   2650000
# 172   1100000
# 175   2200000
# 176   2400000
# ...       ...
# 1340  2070000
# 1341  1650000
# 1343  1850000
# 1351  5195000
# 1368   980000
#
# [139 rows x 12 columns]

# %%
df['Цвет'].fillna(value='белый', inplace=True) # тут, к сожалению, не угадаешь...

# %% [markdown]
# ### Все пропуски обработаны! Ура!

# %%
df.isnull().sum()
# Out:
# Название           0
# Год                0
# Топливо            0
# Объем двигателя    0
# Мощность           0
# Коробка передач    0
# Привод             0
# Цвет               0
# Пробег             0
# Руль               0
# Оценка Drom        0
# Цена               0
# dtype: int64

# %% [markdown]
# Для пущей красоты сделаем пробег целым числом

# %%
df['Пробег'] = df['Пробег'].astype(int)

# %%
df.head(20)
# Out:
#                  Название   Год Топливо  Объем двигателя  Мощность  \
# 0              Kia Mohave  2020  дизель              3.0     260.0
# 1        Hyundai Santa Fe  2018  дизель              2.2     200.0
# 2             Toyota RAV4  2022  бензин              2.0     173.0
# 3          Jeep Gladiator  2020  бензин              3.6     285.0
# 4           Jeep Wrangler  2018  бензин              2.0     272.0
# 5   Mercedes-Benz G-Class  2015  бензин              6.3     544.0
# 6   Mercedes-Benz S-Class  2016  бензин              5.5     585.0
# 7        Лада 2115 Самара  2011  бензин              1.6      81.0
# 8                Kia Soul  2017  бензин              1.6     204.0
# 9                  BMW X5  2014  бензин              3.0     306.0
# 10            Kia Sorento  2018  дизель              2.2     200.0
# 11      Toyota Highlander  2012  бензин              3.5     273.0
# 12           ГАЗ 14 Чайка  1985  бензин              5.5     220.0
# 13          Changan UNI-K  2021  бензин              2.0     232.0
# 14           Kia Carnival  2021  дизель              2.2     199.0
# 15   Hyundai Grand Starex  2010  дизель              2.5     145.0
# 16          Infiniti QX56  2010  бензин              5.6     405.0
# 17                Audi A6  2014  бензин              2.0     180.0
# 18   Hyundai Grand Starex  2011  дизель              2.5     145.0
# 19        Volkswagen Polo  2019  бензин              1.6     110.0
#
#    Коробка передач    Привод         Цвет  Пробег   Руль  Оценка Drom     Цена
# 0          автомат       4WD        серый   26000  левый        8.800  4650000
# 1          автомат       4WD        серый   81000  левый        8.700  2850000
# 2         вариатор       4WD       черный       1  левый        8.700  4000000
# 3          автомат       4WD       черный   15000  левый        8.602  6750000
# 4          автомат       4WD       черный   37700  левый        8.700  5200000
# 5          автомат       4WD       черный   52000  левый        8.900  9000000
# 6            робот       4WD       черный   75000  левый        8.602  8500000
# 7         механика  передний  серебристый  250000  левый        7.600   120000
# 8            робот  передний        белый  121950  левый        8.800  1249000
# 9          автомат       4WD        белый  117389  левый        8.602  2599000
# 10         автомат       4WD   коричневый   83423  левый        8.600  2699000
# 11         автомат       4WD       черный  150851  левый        8.602  1449000
# 12         автомат    задний       черный   39316  левый        8.602  3000000
# 13         автомат       4WD        серый   17000  левый        8.602  3550000
# 14         автомат  передний       черный   20500  левый        8.600  4250000
# 15         автомат    задний        белый  140602  левый        8.600  1349000
# 16         автомат       4WD       черный  155314  левый        8.602  1549000
# 17        вариатор  передний       черный  132664  левый        8.900  1349000
# 18         автомат    задний        серый  143414  левый        8.600  1249000
# 19         автомат  передний        синий   80778  левый        8.600  1099000

# %% [markdown]
# Сохраним эту красоту табличкой

# %%
df.to_csv (r'C:\Users\User\Downloads\data_processed.csv')

# %% [markdown]
# ## III) Визуализация

# %%
df = pd.read_csv('data_processed.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# Итак, данные готовы, пришло время посмотреть на их взаимосвязь. Матрица с корреляциями - неплохой способ получить много информации об этом

# %%
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True);

# %% [markdown]
# Отлично! Наиболее яркими зависимостями получились: Объем двигателя и мощность, год выпуска и пробег, мощность двигателя и цена. Первые две вполни легко объяснимы: чем больше у двигателя объем, тем большую мощность он способен выдать и чем раньше был выпущен автомобиль - тем дольше и дальше он катается по дорогам. Посмотрим на них на наличие всяких интересностей.

# %%
sns.set_style('darkgrid')
plt.title('Зависимость между годом выпуска и пробегом автомобиля',size=16)
plt.xlabel('Пробег',size=12)
plt.ylabel('Год',size=12)
sns.scatterplot(x='Пробег', y='Год', data=df, edgecolor='black', palette='cubehelix')
plt.show()

# %% [markdown]
# Взаимосвязь отрицательная: чем меньше год выпуска, тем больше пробег. Очень логично.

# %%
plt.title('Зависимость между мощностью и объемом двигателя',size=16)
plt.xlabel('Мощность',size=12)
plt.ylabel('Объем двигателя',size=12)
sns.scatterplot(x='Мощность', y='Объем двигателя', data=df, edgecolor='black', palette='cubehelix')
plt.show()

# %% [markdown]
# Можно заметить, что подавляющее большинство составляют новые автомобили с относительно небольшим пробегом, а так же автомобили с относительно невысокой мощностью. Вероятно, это особновано тем, что подавляющее большинство используемых автомобилей - легковые, которые владелец собирается менять на аналогичные, но более новые марки.

# %%
plt.title('Зависимость между мощностью двигателя и ценой автомбиля',size=16)
plt.xlabel('Цена',size=12)
plt.ylabel('Мощность',size=12)
sns.scatterplot(x='Цена', y='Мощность', data=df, edgecolor='black', palette='cubehelix')
plt.show()

# %% [markdown]
# Схожее распределение, показывающее что большинство автомобилей - относительно слабые и дешевые.
#
# Помимо подавляющего большинства на графиках выше также хорошо заметны единичные случаи сильных, дорогих или старых автомобилей.

# %% [markdown]
# Хорошо, с численными переменными все стало немного понятнее. Но что со всем остальным? Давайте посмотрим, что встречается чаще всего

# %%
df.describe(include='object')
# Out:
#        Название Топливо Коробка передач    Привод   Цвет   Руль
# count      1370    1370            1370      1370   1370   1370
# unique      404       3               4         3     15      2
# top     Kia Rio  бензин         автомат  передний  белый  левый
# freq         30    1087             833       653    463   1321

# %% [markdown]
# Если с большей частью столбцов все было понятно еще на этапе обработки данных, то вот узнать, сколько различных марок машин сейчас продается и какая из них самая популярная достаточно интересно.

# %% [markdown]
# Но что если рассматривать по производителям и конкретным моделям?

# %%
data2 = pd.DataFrame()
data2[['Производитель', 'Модель']] = df['Название'].str.split(' ', 1, expand=True)
data2
# Out:
#      Производитель        Модель
# 0              Kia        Mohave
# 1          Hyundai      Santa Fe
# 2           Toyota          RAV4
# 3             Jeep     Gladiator
# 4             Jeep      Wrangler
# ...            ...           ...
# 1365         Volvo          XC60
# 1366          Audi            A8
# 1367           BMW      3-Series
# 1368         Geely  Tugella FY11
# 1369    Volkswagen          Polo
#
# [1370 rows x 2 columns]

# %% [markdown]
# > Как видно, даже отделив Kia от Rio, они все равно остаются самыми популярными среди производителей и моделей соответственно

# %%
data2.describe()
# Out:
#        Производитель Модель
# count           1370   1370
# unique            66    404
# top              Kia    Rio
# freq             148     30
